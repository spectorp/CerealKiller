# %% [markdown]
# # Fine-tune YOLO v3 to detect cereal boxes
#
# Make sure Colab is running on GPU and set to high memory

# %% [markdown]
# ### Clone github repo and mount personal google drive

# %%
# Clone github repo
# !git clone https://github.com/AntonMu/TrainYourOwnYOLO

# Mount Google Drive
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# fatal: destination path 'TrainYourOwnYOLO' already exists and is not an empty directory.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Install requirements

# %%
# Install requirements
# !pip install -r /content/TrainYourOwnYOLO/requirements.txt

# %% [markdown]
# ### Double check CUDA version

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# ### Colab doesn't reliably install the correct version of Tensorflow. Install again.

# %%
# !pip install tensorflow-gpu==1.15

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %% [markdown]
# ### Check hardware

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3184996583441744115, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 13806274092946661886
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12205793408298412779
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8823429802549553462
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %% [markdown]
# ### Check that Google Drive is mounted and accessible

# %%
# !ls "/content/drive/My Drive/Insight/YOLOv3"
# Out:
# data_classes.txt  data_train.txt  yolo.h5

# %% [markdown]
# ### Do necessary file tranfers

# %%
# Remove files from Test_Image_Detection_Results
# !rm /content/TrainYourOwnYOLO/Data/Source_Images/Test_Image_Detection_Results/*.jpg
#!rm /content/TrainYourOwnYOLO/Data/Source_Images/Test_Image_Detection_Results/*.mp4
#!rm /content/TrainYourOwnYOLO/Data/Source_Images/Test_Image_Detection_Results/*.csv

# Remove files from Test_Images
# !rm /content/TrainYourOwnYOLO/Data/Source_Images/Test_Images/*.jpg
#!rm /content/TrainYourOwnYOLO/Data/Source_Images/Test_Images/*.jpeg
#!rm /content/TrainYourOwnYOLO/Data/Source_Images/Test_Images/*.mp4
# !rm /content/TrainYourOwnYOLO/Data/Source_Images/Test_Images/*.JPG

# Remove files from Training_Images
# !rm /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/*.jpg

# Remove files from vott-csv-export
# !rm /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/vott-csv-export/*.jpg
# !rm /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/vott-csv-export/*.csv
# !rm /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/vott-csv-export/*.txt

# Remove data_classes.txt
# !rm /content/TrainYourOwnYOLO/Data/Model_Weights/data_classes.txt

# copy target data and images from Google Drive to Training_Images
# !cp "/content/drive/My Drive/Insight/YOLOv3/data_train.txt" "/content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/vott-csv-export/data_train.txt"
#!cp "/content/drive/My Drive/Insight/YOLOv3/"*.png "/content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/"
# !cp "/content/drive/My Drive/Insight/data/synthesized/PNG/"*.png "/content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/"

# copy data_classes.txt to Model_Weights
# !cp "/content/drive/My Drive/Insight/YOLOv3/data_classes.txt" "/content/TrainYourOwnYOLO/Data/Model_Weights/"

# copy pre-downloaded Model_Weights
# !cp "/content/drive/My Drive/Insight/YOLOv3/yolo.h5" "/content/TrainYourOwnYOLO/2_Training/src/keras_yolo3/"
# Out:
# rm: cannot remove '/content/TrainYourOwnYOLO/Data/Source_Images/Test_Image_Detection_Results/*.jpg': No such file or directory
# rm: cannot remove '/content/TrainYourOwnYOLO/Data/Source_Images/Test_Images/*.jpg': No such file or directory
# rm: cannot remove '/content/TrainYourOwnYOLO/Data/Source_Images/Test_Images/*.JPG': No such file or directory
# rm: cannot remove '/content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/*.jpg': No such file or directory
# rm: cannot remove '/content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/vott-csv-export/*.jpg': No such file or directory
# rm: cannot remove '/content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/vott-csv-export/*.csv': No such file or directory
# rm: cannot remove '/content/TrainYourOwnYOLO/Data/Model_Weights/data_classes.txt': No such file or directory

# %%
# !ls /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/vott-csv-export/
# Out:
# data_train.txt

# %% [markdown]
# ### Train model

# %%
# !python /content/TrainYourOwnYOLO/2_Training/Train_YOLO.py
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0609 02:16:44.746846 139964020328320 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0609 02:16:44.747150 139964020328320 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0609 02:16:44.750406 139964020328320 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %% [markdown]
# ### copy trained model weights to Google Drive

# %%
# !cp "/content/TrainYourOwnYOLO/Data/Model_Weights/trained_weights_final.h5" "/content/drive/My Drive/Insight/YOLOv3"
# !cp "/content/TrainYourOwnYOLO/Data/Model_Weights/trained_weights_stage_1.h5" "/content/drive/My Drive/Insight/YOLOv3"

# %%
# !ls -l /content/TrainYourOwnYOLO/Data/Model_Weights
# Out:
# total 723280
# drwxr-xr-x 2 root root      4096 Jun  9 01:18 1591665517
# drwxr-xr-x 2 root root      4096 Jun  9 01:32 1591666143
# drwxr-xr-x 2 root root      4096 Jun  9 05:24 1591669016
# -rw-r--r-- 1 root root 246867088 Jun  9 05:16 checkpoint.h5
# -rw------- 1 root root        12 Jun  9 02:15 data_classes.txt
# -rw-r--r-- 1 root root      1866 Jun  9 01:13 Download_Weights.py
# -rw-r--r-- 1 root root        86 Jun  9 01:13 Download_Weights.sh
# -rw-r--r-- 1 root root 246867088 Jun  9 05:24 trained_weights_final.h5
# -rw-r--r-- 1 root root 246867088 Jun  9 04:05 trained_weights_stage_1.h5
